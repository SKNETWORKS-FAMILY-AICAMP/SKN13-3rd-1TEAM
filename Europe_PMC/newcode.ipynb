# %%
import requests

def get_search_result_count(query: str) -> int:
    url = "https://www.ebi.ac.uk/europepmc/webservices/rest/search"
    params = {
        "query": query,
        "format": "json",
        "pageSize": 1  # 논문은 안 받고 개수만
    }

    response = requests.get(url, params=params)
    if response.status_code == 200:
        json_data = response.json()
        print("Raw 응답:", json_data)  # 디버깅용 출력
        return int(json_data.get("hitCount", 0))
    else:
        print(f"❌ API 요청 실패: {response.status_code}")
        return 0

query = '("antibiotic overuse" OR "vitamin C" OR "mRNA vaccine" OR "inflammation" OR "immunotherapy" OR "low carb diet" OR "mental health stigma" OR "supplements" OR "herbal medicine") AND PUB_YEAR:2025'
count = get_search_result_count(query)
print("🔎 검색된 논문 수:", count)
# Out:
# Raw 응답: {'version': '6.9', 'hitCount': 144937, 'nextCursorMark': 'AoIIQbTxkyg1MzA1Nzg5OQ==', 'nextPageUrl': 'https://www.ebi.ac.uk/europepmc/webservices/rest/search?query=("antibiotic overuse" OR "vitamin C" OR "mRNA vaccine" OR "inflammation" OR "immunotherapy" OR "low carb diet" OR "mental health stigma" OR "supplements" OR "herbal medicine") AND PUB_YEAR:2025&cursorMark=AoIIQbTxkyg1MzA1Nzg5OQ==&resultType=lite&pageSize=1&format=json', 'request': {'queryString': '("antibiotic overuse" OR "vitamin C" OR "mRNA vaccine" OR "inflammation" OR "immunotherapy" OR "low carb diet" OR "mental health stigma" OR "supplements" OR "herbal medicine") AND PUB_YEAR:2025', 'resultType': 'lite', 'cursorMark': '*', 'pageSize': 1, 'sort': '', 'synonym': False}, 'resultList': {'result': [{'id': '40433834', 'source': 'MED', 'pmid': '40433834', 'doi': '10.1111/pde.15998', 'title': 'Inflamed or Infected Molluscum Contagiosum Lesions: Pediatrician Perceptions and the Risk of Antibiotic Overuse.', 'authorString': 'Young T, Wei J, Wan J, Yan AC.', 'journalTitle': 'Pediatr Dermatol', 'pubYear': '2025', 'journalIssn': '0736-8046; 1525-1470; ', 'pubType': 'journal article', 'isOpenAccess': 'N', 'inEPMC': 'N', 'inPMC': 'N', 'hasPDF': 'N', 'hasBook': 'N', 'hasSuppl': 'N', 'citedByCount': 0, 'hasReferences': 'Y', 'hasTextMinedTerms': 'Y', 'hasDbCrossReferences': 'N', 'hasLabsLinks': 'Y', 'hasTMAccessionNumbers': 'N', 'firstIndexDate': '2025-05-28', 'firstPublicationDate': '2025-05-28'}]}}
# 🔎 검색된 논문 수: 144937

# %%
import os
import time
import requests
from bs4 import BeautifulSoup
from pathlib import Path
from dotenv import load_dotenv
from concurrent.futures import ThreadPoolExecutor, as_completed
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma
import tqdm
from dotenv import load_dotenv
import os

# ✅ 환경 변수 로딩 (.env에 OPENAI_API_KEY 포함되어야 함)
load_dotenv(dotenv_path="C:/Aicamp/SKN13_my/13_Langchain/.env")

# ✅ 글로벌 상수 설정
COLLECTION_NAME = "paper_db"
PERSIST_DIR = "vector_store/chroma"
EMBEDDING_MODEL = OpenAIEmbeddings(model="text-embedding-3-large")


def safe_request_get(url, params=None, headers=None, retries=5, backoff=2, timeout=10):
    """안정적인 GET 요청 함수 (재시도 포함)"""
    for attempt in range(retries):
        try:
            response = requests.get(url, params=params, headers=headers, timeout=timeout)
            response.raise_for_status()
            return response
        except requests.exceptions.RequestException as e:
            print(f"요청 실패 ({attempt + 1}/{retries}): {e}")
            time.sleep(backoff * (attempt + 1))
    raise Exception(f"최대 재시도 초과: {url}")


def extract_pmc_fulltext(pmcid):
    """PMC 논문 페이지에서 본문 텍스트 추출 (300자 이상)"""
    url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmcid}/"
    headers = {"User-Agent": "Mozilla/5.0"}
    res = safe_request_get(url, headers=headers)
    soup = BeautifulSoup(res.text, "html.parser")

    paragraphs = soup.select("p")
    text_blocks = [p.get_text(strip=True) for p in paragraphs if p.get_text(strip=True)]
    full_text = "\n\n".join(text_blocks).strip()

    if len(full_text) < 300:
        raise Exception(f"본문 길이 부족: {len(full_text)}자")

    return full_text, url


def chunk_text_to_documents(text, source_url, r):
    """본문을 Chunk로 분할하고 LangChain Document로 반환"""
    splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
    docs = splitter.create_documents([text])
    metadata = {
        "source": source_url,
        "pmcid": r.get("pmcid"),
        "title": r.get("title"),
        "doi": r.get("doi"),
        "pubYear": r.get("pubYear"),
        "journal": r.get("journalTitle"),
        "authors": r.get("authorString"),
        "abstract": r.get("abstractText")
    }
    for doc in docs:
        doc.metadata = metadata
    return docs


def get_existing_pmcids():
    """이미 Chroma DB에 저장된 PMC ID 목록 반환"""
    vector_store = Chroma(
        collection_name=COLLECTION_NAME,
        embedding_function=EMBEDDING_MODEL,
        persist_directory=PERSIST_DIR
    )
    metadatas = vector_store.get().get("metadatas", [])
    return {m.get("pmcid") for m in metadatas if m and m.get("pmcid")}


def store_documents(docs):
    """문서 리스트를 벡터 DB에 저장하고 결과 상태 반환"""
    pmcid = docs[0].metadata["pmcid"]
    existing_pmcs = get_existing_pmcids()

    if pmcid in existing_pmcs:
        return "중복으로 pass"

    try:
        vector_store = Chroma(
            collection_name=COLLECTION_NAME,
            embedding_function=EMBEDDING_MODEL,
            persist_directory=PERSIST_DIR
        )
        vector_store.add_documents(docs)
        return "성공"
    except Exception as e:
        return f"실패: {e}"


def process_single_article(r, current_index, total_count):
    """단일 논문 처리: 본문 추출 → chunk → 저장 → 결과 메시지 반환"""
    pmcid = r.get("pmcid")
    if not pmcid:
        return f"[{current_index}/{total_count}] PMCID 없음 → 실패"

    try:
        text, url = extract_pmc_fulltext(pmcid)
        docs = chunk_text_to_documents(text, url, r)
        result = store_documents(docs)
        return f"[{current_index}/{total_count}] {pmcid} 처리 결과: {result}"
    except Exception as e:
        return f"[{current_index}/{total_count}] {pmcid} 처리 실패: {str(e)}"


def process_all_pmc_articles(query):
    """
    유럽 PMC API를 통해 논문 메타데이터를 수집하고,
    각 논문을 병렬로 처리하여 벡터 DB에 저장합니다.
    """
    cursor = "*"
    page_size = 25
    index_counter = 1
    total_expected = None
    existing_pmcs = get_existing_pmcids()

    while True:
        res = safe_request_get(
            "https://www.ebi.ac.uk/europepmc/webservices/rest/search",
            params={"query": query, "format": "json", "pageSize": page_size, "cursorMark": cursor}
        )
        data = res.json()
        results = data.get("resultList", {}).get("result", [])

        if not results:
            break

        filtered = [r for r in results if r.get("pmcid") not in existing_pmcs]
        total_expected = total_expected or data.get("hitCount", len(filtered))

        with ThreadPoolExecutor(max_workers=5) as executor:
            futures = [
                executor.submit(process_single_article, r, index_counter + i, total_expected)
                for i, r in enumerate(filtered)
            ]
            for future in as_completed(futures):
                print(future.result())

        cursor = data.get("nextCursorMark")
        index_counter += len(results)
        if not cursor:
            break

# %%
if __name__ == "__main__":
    query = '("coffee consumption" AND "health") AND PUB_YEAR:2025'
    process_all_pmc_articles(query)
# Out:
# [4/400] PMCID 없음 → 실패
# [6/400] PMCID 없음 → 실패
# [5/400] PMCID 없음 → 실패
# [9/400] PMCID 없음 → 실패
# [1/400] PMCID 없음 → 실패
# [7/400] PMCID 없음 → 실패
# [10/400] PMCID 없음 → 실패
# [12/400] PMCID 없음 → 실패
# [13/400] PMC11944175 처리 결과: 성공
# [14/400] PMCID 없음 → 실패
# [15/400] PMCID 없음 → 실패
# [11/400] PMC12021940 처리 결과: 성공
# [17/400] PMCID 없음 → 실패
# [18/400] PMCID 없음 → 실패
# [19/400] PMCID 없음 → 실패
# [2/400] PMC11909266 처리 결과: 성공
# [21/400] PMCID 없음 → 실패
# [8/400] PMC12037506 처리 결과: 성공
# [23/400] PMCID 없음 → 실패
# [24/400] PMCID 없음 → 실패
# [25/400] PMCID 없음 → 실패
# [3/400] PMC12073867 처리 결과: 성공
# 요청 실패 (1/5): HTTPSConnectionPool(host='www.ncbi.nlm.nih.gov', port=443): Max retries exceeded with url: /pmc/articles/PMC11978573/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001C1EA7DA600>, 'Connection to www.ncbi.nlm.nih.gov timed out. (connect timeout=10)'))
# [20/400] PMC11853883 처리 결과: 성공
# [16/400] PMC11948776 처리 결과: 성공
# [22/400] PMC11978573 처리 결과: 성공
# [27/400] PMCID 없음 → 실패
# [26/400] PMCID 없음 → 실패
# [28/400] PMCID 없음 → 실패
# [33/400] PMCID 없음 → 실패
# [29/400] PMC11925710 처리 결과: 성공
# [35/400] PMCID 없음 → 실패
# [31/400] PMC12168468 처리 결과: 성공
# [30/400] PMC12166192 처리 결과: 성공
# [34/400] PMC12157705 처리 결과: 성공
# [32/400] PMC11990472 처리 결과: 성공
# [36/400] PMC11913691 처리 결과: 성공
# [41/400] PMCID 없음 → 실패
# [37/400] PMC11939571 처리 결과: 성공
# [39/400] PMC12192561 처리 결과: 성공
# [38/400] PMC12063011 처리 결과: 성공
# [40/400] PMC11917380 처리 결과: 성공
# [42/400] PMC12193296 처리 결과: 성공
# [47/400] PMCID 없음 → 실패
# [45/400] PMC11699235 처리 결과: 성공
# [46/400] PMC12179055 처리 결과: 성공
# [43/400] PMC12028545 처리 결과: 성공
# [44/400] PMC11843000 처리 결과: 성공
# [48/400] PMC12170853 처리 결과: 성공
# [50/400] PMC12152502 처리 결과: 성공
# [49/400] PMC11705407 처리 결과: 성공
# [57/400] PMCID 없음 → 실패
# [54/400] PMCID 없음 → 실패
# [53/400] PMCID 없음 → 실패
# [58/400] PMC11919296 처리 결과: 성공
# [59/400] PMCID 없음 → 실패
# [60/400] PMCID 없음 → 실패
# [52/400] PMC12025826 처리 결과: 성공
# [62/400] PMCID 없음 → 실패
# [55/400] PMC12040487 처리 결과: 성공
# [64/400] PMCID 없음 → 실패
# [65/400] PMCID 없음 → 실패
# [51/400] PMC11875359 처리 결과: 성공
# [56/400] PMC11747435 처리 결과: 성공
# [61/400] PMC12145794 처리 결과: 성공
# [63/400] PMC11823423 처리 결과: 성공
# [68/400] PMC12178019 처리 결과: 성공
# [66/400] PMC11973162 처리 결과: 성공
# [67/400] PMC12132729 처리 결과: 성공
# [69/400] PMC12073117 처리 결과: 성공
# [70/400] PMC11785678 처리 결과: 성공
# [74/400] PMC12021833 처리 결과: 성공
# [71/400] PMC12015906 처리 결과: 성공
# [72/400] PMC11707279 처리 결과: 성공
# [73/400] PMC11950924 처리 결과: 성공
# [76/400] PMCID 없음 → 실패
# [79/400] PMCID 없음 → 실패
# [80/400] PMCID 없음 → 실패
# [81/400] PMC11739192 처리 결과: 성공
# [83/400] PMC11835096 처리 결과: 성공
# [78/400] PMC12188028 처리 결과: 성공
# [86/400] PMCID 없음 → 실패
# [82/400] PMC11865779 처리 결과: 성공
# [88/400] PMCID 없음 → 실패
# [77/400] PMC12061895 처리 결과: 성공
# [84/400] PMC11806617 처리 결과: 성공
# [85/400] PMC11952159 처리 결과: 성공
# [91/400] PMC12056639 처리 결과: 성공
# [87/400] PMC11901579 처리 결과: 성공
# [89/400] PMC12008579 처리 결과: 성공
# [90/400] PMC12163779 처리 결과: 성공
# [96/400] PMCID 없음 → 실패
# [92/400] PMC11717776 처리 결과: 성공
# [93/400] PMC12116101 처리 결과: 성공
# [94/400] PMC11913531 처리 결과: 성공
# [97/400] PMC12129752 처리 결과: 성공
# [98/400] PMC7616751 처리 결과: 성공
# [95/400] PMC11733827 처리 결과: 성공
# [99/400] PMC12063232 처리 결과: 성공
# [100/400] PMC12013330 처리 결과: 성공
# [105/400] PMCID 없음 → 실패
# [101/400] PMC11883496 처리 결과: 성공
# [102/400] PMC12129501 처리 결과: 성공
# [108/400] PMCID 없음 → 실패
# [103/400] PMC11699412 처리 결과: 성공
# [106/400] PMC11867817 처리 결과: 성공
# [104/400] PMC11760116 처리 결과: 성공
# [112/400] PMCID 없음 → 실패
# [113/400] PMCID 없음 → 실패
# [107/400] PMC11817413 처리 결과: 성공
# [110/400] PMC12107659 처리 결과: 성공
# [109/400] PMC11748866 처리 결과: 성공
# [114/400] PMC12154222 처리 결과: 성공
# [111/400] PMC11901526 처리 결과: 성공
# [115/400] PMC12125613 처리 결과: 성공
# [119/400] PMC12026650 처리 결과: 성공
# [116/400] PMC11852448 처리 결과: 성공
# [117/400] PMC11846199 처리 결과: 성공
# [118/400] PMC11946014 처리 결과: 성공
# [120/400] PMC11948628 처리 결과: 성공
# [121/400] PMC11858445 처리 결과: 성공
# [123/400] PMC11973067 처리 결과: 성공
# [124/400] PMC11779499 처리 결과: 성공
# [122/400] PMC12163221 처리 결과: 성공
# [127/400] PMCID 없음 → 실패
# [126/400] PMC11906831 처리 결과: 성공
# [128/400] PMC11801795 처리 결과: 성공
# [129/400] PMC11852120 처리 결과: 성공
# [131/400] PMC11951490 처리 결과: 성공
# [130/400] PMC11726935 처리 결과: 성공
# [132/400] PMC12028811 처리 결과: 성공
# [133/400] PMC11900378 처리 결과: 성공
# [134/400] PMC12055963 처리 결과: 성공
# [139/400] PMCID 없음 → 실패
# [135/400] PMC11882227 처리 결과: 성공
# [136/400] PMC12027362 처리 결과: 성공
# [137/400] PMC11695618 처리 결과: 성공
# [138/400] PMC11723161 처리 결과: 성공
# [140/400] PMC12113164 처리 결과: 성공
# [142/400] PMC11766447 처리 결과: 성공
# [141/400] PMC12058169 처리 결과: 성공
# [144/400] PMC11887121 처리 결과: 성공
# [143/400] PMC12192880 처리 결과: 성공
# [145/400] PMC11826089 처리 결과: 성공
# [146/400] PMC11792182 처리 결과: 성공
# [147/400] PMC11737007 처리 결과: 성공
# [148/400] PMC12125738 처리 결과: 성공
# [149/400] PMC12110598 처리 결과: 성공
# [150/400] PMC12009456 처리 결과: 성공
# [152/400] PMC12158849 처리 결과: 성공
# [154/400] PMC11946849 처리 결과: 성공
# [153/400] PMC12096783 처리 결과: 성공
# [155/400] PMC12065086 처리 결과: 성공
# [151/400] PMC11806811 처리 결과: 성공
# [156/400] PMC12173863 처리 결과: 성공
# [157/400] PMC11932285 처리 결과: 성공
# [158/400] PMC12083291 처리 결과: 성공
# 요청 실패 (1/5): HTTPSConnectionPool(host='www.ncbi.nlm.nih.gov', port=443): Read timed out. (read timeout=10)
# [160/400] PMC11989194 처리 결과: 성공
# [159/400] PMC12115761 처리 결과: 성공
# [165/400] PMCID 없음 → 실패
# [161/400] PMC12157282 처리 결과: 성공
# [163/400] PMC11869732 처리 결과: 성공
# [162/400] PMC11959088 처리 결과: 성공
# [164/400] PMC11874124 처리 결과: 성공
# [166/400] PMC11951505 처리 결과: 성공
# [167/400] PMC12147739 처리 결과: 성공
# [169/400] PMC12153008 처리 결과: 성공
# [171/400] PMC11986549 처리 결과: 성공
# [170/400] PMC12003230 처리 결과: 성공
# [168/400] PMC11809266 처리 결과: 성공
# [172/400] PMC11890636 처리 결과: 성공
# [173/400] PMC11785613 처리 결과: 성공
# [180/400] PMC12038625 처리 결과: 성공
# [176/400] PMC11983728 처리 결과: 성공
# [177/400] PMC11986461 처리 결과: 성공
# [179/400] PMC11856214 처리 결과: 성공
# [178/400] PMC12183343 처리 결과: 성공
# [181/400] PMC12083014 처리 결과: 성공
# [183/400] PMC11701871 처리 결과: 성공
# [185/400] PMC12001358 처리 결과: 성공
# [182/400] PMC11937534 처리 결과: 성공
# [184/400] PMC12059117 처리 결과: 성공
# [186/400] PMC11872501 처리 결과: 성공
# [187/400] PMC11696681 처리 결과: 성공
# [189/400] PMC12113525 처리 결과: 성공
# [190/400] PMC12137563 처리 결과: 성공
# [188/400] PMC11892917 처리 결과: 성공
# [191/400] PMC11907354 처리 결과: 성공
# [192/400] PMC12042177 처리 결과: 성공
# [194/400] PMC12119133 처리 결과: 성공
# [193/400] PMC11942281 처리 결과: 성공
# [195/400] PMC12163218 처리 결과: 성공
# [196/400] PMC11864305 처리 결과: 성공
# [197/400] PMC12144590 처리 결과: 성공
# [199/400] PMC11980264 처리 결과: 성공
# [198/400] PMC11915747 처리 결과: 성공
# [200/400] PMC11815699 처리 결과: 성공
# [205/400] PMC11981246 처리 결과: 성공
# [204/400] PMC12187298 처리 결과: 성공
# [201/400] PMC12138951 처리 결과: 성공
# [203/400] PMC11982716 처리 결과: 성공
# [202/400] PMC11716994 처리 결과: 성공
# [206/400] PMC12157199 처리 결과: 성공
# [207/400] PMC11893433 처리 결과: 성공
# [209/400] PMC12165471 처리 결과: 성공
# [208/400] PMC12105385 처리 결과: 성공
# [210/400] PMC11943489 처리 결과: 성공
# [211/400] PMC12173857 처리 결과: 성공
# [212/400] PMC11849416 처리 결과: 성공
# [213/400] PMC11753015 처리 결과: 성공
# 요청 실패 (1/5): HTTPSConnectionPool(host='www.ncbi.nlm.nih.gov', port=443): Read timed out. (read timeout=10)
# [216/400] PMC12113040 처리 결과: 성공
# [215/400] PMC11953139 처리 결과: 성공
# [214/400] PMC11857841 처리 결과: 성공
# [217/400] PMC12090469 처리 결과: 성공
# [218/400] PMC12156609 처리 결과: 성공
# [219/400] PMC11867768 처리 결과: 성공
# [220/400] PMC11986178 처리 결과: 성공
# [222/400] PMC12018250 처리 결과: 성공
# [221/400] PMC11939298 처리 결과: 성공
# [223/400] PMC12086266 처리 결과: 성공
# [224/400] PMC12169986 처리 결과: 성공
# [228/400] PMC11902183 처리 결과: 성공
# [227/400] PMC12151456 처리 결과: 성공
# [230/400] PMC11770431 처리 결과: 성공
# [229/400] PMC12166168 처리 결과: 성공
# [226/400] PMC11851918 처리 결과: 성공
# [231/400] PMC12089529 처리 결과: 성공
# [232/400] PMC12026888 처리 결과: 성공
# [234/400] PMC11697462 처리 결과: 성공
# [233/400] PMC11920367 처리 결과: 성공
# [235/400] PMC12058179 처리 결과: 성공
# [237/400] PMC12104077 처리 결과: 성공
# [236/400] PMC11893546 처리 결과: 성공
# [239/400] PMC11746971 처리 결과: 성공
# [240/400] PMC11853328 처리 결과: 성공
# [238/400] PMC11853636 처리 결과: 성공
# [242/400] PMC12037513 처리 결과: 성공
# [241/400] PMC12158744 처리 결과: 성공
# [244/400] PMC11820191 처리 결과: 성공
# [243/400] PMC12180673 처리 결과: 성공
# [245/400] PMC12159889 처리 결과: 성공
# [246/400] PMC12181851 처리 결과: 성공
# [247/400] PMC12157813 처리 결과: 성공
# [249/400] PMC12123878 처리 결과: 성공
# [248/400] PMC12098573 처리 결과: 성공
# [253/400] PMC12119504 처리 결과: 성공
# [256/400] PMCID 없음 → 실패
# [255/400] PMC12113781 처리 결과: 성공
# [251/400] PMC12114188 처리 결과: 성공
# [252/400] PMC12065867 처리 결과: 성공
# [254/400] PMC11850308 처리 결과: 성공
# [257/400] PMC11945102 처리 결과: 성공
# [259/400] PMC11805386 처리 결과: 성공
# [258/400] PMC12106371 처리 결과: 성공
# [261/400] PMC11982512 처리 결과: 성공
# [260/400] PMC12191915 처리 결과: 성공
# [262/400] PMC12091593 처리 결과: 성공
# [263/400] PMC12003919 처리 결과: 성공
# [266/400] PMC11802704 처리 결과: 성공
# [265/400] PMC11812317 처리 결과: 성공
# [264/400] PMC11841710 처리 결과: 성공
# [267/400] PMC11845551 처리 결과: 성공
# [268/400] PMC12120081 처리 결과: 성공
# [269/400] PMC11855844 처리 결과: 성공
# [272/400] PMC11818911 처리 결과: 성공
# [273/400] PMC11863451 처리 결과: 성공
# [271/400] PMC11967760 처리 결과: 성공
# [270/400] PMC11817741 처리 결과: 성공
# [274/400] PMC11771105 처리 결과: 성공
# [277/400] PMC11886607 처리 결과: 성공
# [276/400] PMC11858716 처리 결과: 성공
# [280/400] PMC11855509 처리 결과: 성공
# [279/400] PMC11720087 처리 결과: 성공
# [278/400] PMC11902253 처리 결과: 성공
# [281/400] PMC12028647 처리 결과: 성공
# [282/400] PMC12066229 처리 결과: 성공
# [285/400] PMC11940589 처리 결과: 성공
# [284/400] PMC11863414 처리 결과: 성공
# [283/400] PMC11750088 처리 결과: 성공
# [286/400] PMC11786655 처리 결과: 성공
# [288/400] PMC11832405 처리 결과: 성공
# [290/400] PMC11700110 처리 결과: 성공
# [289/400] PMC11944921 처리 결과: 성공
# [287/400] PMC11981339 처리 결과: 성공
# [291/400] PMC11992808 처리 결과: 성공
# [292/400] PMC11607108 처리 결과: 성공
# [294/400] PMC11736428 처리 결과: 성공
# [293/400] PMC12033246 처리 결과: 성공요청 실패 (1/5): HTTPSConnectionPool(host='www.ncbi.nlm.nih.gov', port=443): Read timed out. (read timeout=10)
#
# [295/400] PMC12149183 처리 결과: 성공
# [296/400] PMC11895678 처리 결과: 성공
# [297/400] PMC11990436 처리 결과: 성공
# [298/400] PMC11771718 처리 결과: 성공
# [305/400] PMC11901585 처리 결과: 성공
# [304/400] PMC12111376 처리 결과: 성공
# [301/400] PMC11940337 처리 결과: 성공
# [303/400] PMC11839990 처리 결과: 성공
# [302/400] PMC11765590 처리 결과: 성공
# [306/400] PMC11742403 처리 결과: 성공
# [310/400] PMC12029220 처리 결과: 성공
# [309/400] PMC12073803 처리 결과: 성공
# [307/400] PMC11925442 처리 결과: 성공
# [308/400] PMC11900212 처리 결과: 성공
# [311/400] PMC12143172 처리 결과: 성공
# [313/400] PMC11808190 처리 결과: 성공
# [314/400] PMC11763043 처리 결과: 성공
# [315/400] PMC11941026 처리 결과: 성공
# [312/400] PMC12170641 처리 결과: 성공
# [316/400] PMC11848666 처리 결과: 성공
# [319/400] PMC11737816 처리 결과: 성공
# [317/400] PMC12002467 처리 결과: 성공
# [318/400] PMC12038348 처리 결과: 성공
# [322/400] PMC11857234 처리 결과: 성공
# [320/400] PMC12119289 처리 결과: 성공
# [321/400] PMC12022887 처리 결과: 성공
# [323/400] PMC12070717 처리 결과: 성공
# [330/400] PMC12069452 처리 결과: 성공
# [327/400] PMC12180059 처리 결과: 성공
# [329/400] PMC11811143 처리 결과: 성공
# [328/400] PMC11999315 처리 결과: 성공
# [326/400] PMC11880553 처리 결과: 성공
# [335/400] PMC11934668 처리 결과: 성공
# [333/400] PMC11749886 처리 결과: 성공
# [334/400] PMC11841311 처리 결과: 성공
# [332/400] PMC11974087 처리 결과: 성공
# [331/400] PMC11816745 처리 결과: 성공
# [336/400] PMC11800288 처리 결과: 성공
# [340/400] PMC11936622 처리 결과: 성공
# [337/400] PMC11750975 처리 결과: 성공
# [338/400] PMC11988157 처리 결과: 성공
# [339/400] PMC12027308 처리 결과: 성공
# [341/400] PMC11858080 처리 결과: 성공
# [344/400] PMC11817656 처리 결과: 성공
# [342/400] PMC11765469 처리 결과: 성공
# [343/400] PMC12024932 처리 결과: 성공
# [345/400] PMC12076965 처리 결과: 성공
# [346/400] PMC12013446 처리 결과: 성공
# [347/400] PMC11744464 처리 결과: 성공
# [349/400] PMC12016383 처리 결과: 성공
# [348/400] PMC11421999 처리 결과: 성공
# [352/400] PMC11968518 처리 결과: 성공
# [353/400] PMC11582525 처리 결과: 성공
# [355/400] PMC11771800 처리 결과: 성공
# [354/400] PMC12171531 처리 결과: 성공
# [351/400] PMC11574704 처리 결과: 성공
# [356/400] PMC11816379 처리 결과: 성공
# [360/400] PMC12181526 처리 결과: 성공
# [357/400] PMC11703537 처리 결과: 성공
# [358/400] PMC12180816 처리 결과: 성공
# [359/400] PMC12069093 처리 결과: 성공
# [361/400] PMC12112075 처리 결과: 성공
# [364/400] PMC11873865 처리 결과: 성공
# [363/400] PMC11888883 처리 결과: 성공
# [362/400] PMC11984981 처리 결과: 성공
# [365/400] PMC11964658 처리 결과: 성공
# [366/400] PMC11756171 처리 결과: 성공
# [367/400] PMC11857836 처리 결과: 성공
# [368/400] PMC11820484 처리 결과: 성공
# [369/400] PMC12043282 처리 결과: 성공
# [370/400] PMC11793779 처리 결과: 성공
# [371/400] PMC11790578 처리 결과: 성공
# [375/400] PMC11680498 처리 결과: 성공
# [373/400] PMC11909585 처리 결과: 성공
# [374/400] PMC11988898 처리 결과: 성공
# [372/400] PMC11817325 처리 결과: 성공
# [379/400] PMC11855569 처리 결과: 성공
# [380/400] PMC11767999 처리 결과: 성공
# [376/400] PMC11863745 처리 결과: 성공
# [378/400] PMC11702477 처리 결과: 성공
# [377/400] PMC11855179 처리 결과: 성공
# [381/400] PMC11905674 처리 결과: 성공
# [385/400] PMC11743123 처리 결과: 성공
# [383/400] PMC12172134 처리 결과: 성공
# [384/400] PMC11754988 처리 결과: 성공
# [382/400] PMC12044448 처리 결과: 성공
# [386/400] PMC11870817 처리 결과: 성공
# [387/400] PMC12003457 처리 결과: 성공
# [389/400] PMC12014546 처리 결과: 성공
# [390/400] PMC11846878 처리 결과: 성공
# [388/400] PMC11739177 처리 결과: 성공
# [391/400] PMC11781347 처리 결과: 성공
# [392/400] PMC11667106 처리 결과: 성공
# [394/400] PMC11705863 처리 결과: 성공
# [396/400] PMC11729847 처리 결과: 성공
# [393/400] PMC11792134 처리 결과: 성공
# [397/400] PMC12168493 처리 결과: 성공
# [398/400] PMC12155586 처리 결과: 성공
# [399/400] PMC11733248 처리 결과: 성공
# [395/400] PMC12119593 처리 결과: 성공

# %%
# # 유럽 PMC 논문 크롤링 + 전처리 + 벡터 DB 저장 (RAG용 최적화 리팩터링)

# import os
# import time
# import requests
# from bs4 import BeautifulSoup
# from pathlib import Path
# from dotenv import load_dotenv
# from concurrent.futures import ThreadPoolExecutor, as_completed
# from langchain.text_splitter import RecursiveCharacterTextSplitter
# from langchain_core.documents import Document
# from langchain_openai import OpenAIEmbeddings
# from langchain_chroma import Chroma
# import tqdm

# # .env 파일에서 환경변수 불러오기
# load_dotenv(dotenv_path=Path("C:/Aicamp/SKN13_my/13_Langchain/.env"))

# def safe_request_get(url, params=None, headers=None, retries=5, backoff=2, timeout=10):
#     """
#     안전한 GET 요청 함수. 실패 시 재시도(backoff 포함).
#     """
#     for attempt in range(retries):
#         try:
#             print(f"요청 중: {url}")
#             response = requests.get(url, params=params, headers=headers, timeout=timeout)
#             response.raise_for_status()
#             return response
#         except requests.exceptions.RequestException as e:
#             print(f"요청 실패 ({attempt+1}/{retries}): {e}")
#             time.sleep(backoff * (attempt + 1))
#     raise Exception(f"요청 실패: {url}")

# def extract_pmc_fulltext(pmcid):
#     """
#     PMC 논문의 본문 HTML에서 <p> 태그만 추출하여 텍스트로 반환합니다.
#     300자 미만일 경우 예외를 발생시킵니다.
#     """
#     url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmcid}/"
#     headers = {"User-Agent": "Mozilla/5.0"}
#     res = safe_request_get(url, headers=headers)
#     soup = BeautifulSoup(res.text, "html.parser")

#     sections = soup.select("p")
#     if not sections:
#         raise Exception(f"본문 p 태그 없음: {url}")

#     text_blocks = [p.get_text(strip=True) for p in sections if p.get_text(strip=True)]
#     if not text_blocks:
#         raise Exception(f"텍스트 블록 없음: {url}")

#     full_text = "\n\n".join(text_blocks).strip()
#     if len(full_text) < 300: # 내용이 짧아, 신뢰성 결여
#         raise Exception(f"내용 너무 짧음 ({len(full_text)}자): {url}")

#     return full_text, url

# def chunk_text_to_documents(text, source_url, r):
#     """
#     본문 텍스트를 일정 길이로 분할하고, 논문 메타데이터를 부여하여 Document 리스트를 생성합니다.
#     """
#     splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200) # 업계 표준 설정
#     docs = splitter.create_documents([text])
#     metadata_common = {
#         "source": source_url,
#         "pmcid": r.get("pmcid"),
#         "title": r.get("title"),
#         "doi": r.get("doi"),
#         "pubYear": r.get("pubYear"),
#         "journal": r.get("journalTitle"),
#         "authors": r.get("authorString"),
#         "abstract": r.get("abstractText")
#     }
#     for doc in docs:
#         doc.metadata = metadata_common
#     return docs

# def store_documents_to_chroma(docs, collection_name="paper_db", persist_dir="vector_store/chroma", doc_counter=[0]):
#     """
#     Chroma 벡터 DB에 문서 리스트를 저장합니다. 중복 PMC ID는 건너뜁니다.
#     """
#     embedding_model = OpenAIEmbeddings(model="text-embedding-3-large")
#     vector_store = Chroma(
#         collection_name=collection_name,
#         embedding_function=embedding_model,
#         persist_directory=persist_dir
#     )
#     existing_pmcs = {
#         metadata.get("pmcid") for metadata in vector_store.get().get("metadatas", []) if metadata
#     }
#     new_docs = [doc for doc in docs if doc.metadata["pmcid"] not in existing_pmcs]

#     if new_docs:
#         vector_store.add_documents(new_docs)
#         doc_counter[0] += 1
#         print(f"문서 저장 완료 (총 {doc_counter[0]}번째 논문)")
#     else:
#         print("중복 문서로 저장 생략")

# def count_documents(collection_name="paper_db", persist_dir="vector_store/chroma"):
#     """
#     Chroma DB에 저장된 전체 문서 수를 반환합니다.
#     """
#     vector_store = Chroma(
#         collection_name=collection_name,
#         persist_directory=persist_dir,
#         embedding_function=OpenAIEmbeddings(model="text-embedding-3-large")
#     )
#     return len(vector_store.get().get("documents", []))

# def count_existing_articles(collection_name="paper_db", persist_dir="vector_store/chroma"):
#     """
#     중복 방지를 위해 Chroma DB에 저장된 고유 PMC ID 수를 반환합니다.
#     """
#     vector_store = Chroma(
#         collection_name=collection_name,
#         persist_directory=persist_dir,
#         embedding_function=OpenAIEmbeddings(model="text-embedding-3-large")
#     )
#     metadatas = vector_store.get().get("metadatas", [])
#     pmcids = {m.get("pmcid") for m in metadatas if m and m.get("pmcid")}
#     return len(pmcids)

# def get_existing_pmcids(collection_name="paper_db", persist_dir="vector_store/chroma"):
#     """
#     벡터 DB에서 현재 저장된 PMC ID 목록을 반환합니다.
#     """
#     vector_store = Chroma(
#         collection_name=collection_name,
#         persist_directory=persist_dir,
#         embedding_function=OpenAIEmbeddings(model="text-embedding-3-large")
#     )
#     metadatas = vector_store.get().get("metadatas", [])
#     return {m.get("pmcid") for m in metadatas if m and m.get("pmcid")}

# def process_single_article(r, index, doc_counter):
#     """
#     단일 논문 처리 루틴.
#     - 본문 추출
#     - 분할 및 메타데이터 추가
#     - 벡터 DB 저장
#     """
#     pmcid = r.get("pmcid")
#     if not pmcid:
#         print("PMCID 없음")
#         return False
#     print(f"논문 {index}: {pmcid} - {r.get('title')}")
#     try:
#         text, source_url = extract_pmc_fulltext(pmcid)
#         docs = chunk_text_to_documents(text, source_url, r)
#         store_documents_to_chroma(docs, doc_counter=doc_counter)
#         return True
#     except Exception as e:
#         print(f"처리 실패: {e}")
#         return False



# def process_all_pmc_articles(query):
#     """
#     Europe PMC API를 통해 질의(query)에 해당하는 논문들을 수집하고 처리합니다.
#     - 중복 PMCID는 건너뜁니다
#     - 병렬 처리 (ThreadPoolExecutor)
#     - 크롤링 재개 가능성 고려 (중단 시 이어서 실행)
#     """
#     cursor = "*"
#     page_size = 25
#     total = 0
#     index_counter = 1
#     doc_counter = [count_existing_articles()]
#     existing_pmcids = get_existing_pmcids()

#     pbar = tqdm.tqdm(desc="전체 처리", unit="논문")

#     while True:
#         res = safe_request_get(
#             "https://www.ebi.ac.uk/europepmc/webservices/rest/search",
#             params={"query": query, "format": "json", "pageSize": page_size, "cursorMark": cursor}
#         )
#         data = res.json()
#         results = data.get("resultList", {}).get("result", [])
#         if not results:
#             break

#         filtered_results = [r for r in results if r.get("pmcid") not in existing_pmcids]

#         with ThreadPoolExecutor(max_workers=5) as executor:
#             futures = {
#                 executor.submit(process_single_article, r, index, doc_counter): r
#                 for index, r in enumerate(filtered_results, start=index_counter)
#             }
#             for f in as_completed(futures):
#                 if f.result():
#                     total += 1
#                     pbar.update(1)

#         index_counter += len(results)
#         cursor = data.get("nextCursorMark")
#         if not cursor:
#             break

#     pbar.close()
#     print(f"저장한 논문 수: {total}")
#     print(f"현재 DB 내 전체 문서 수: {count_documents()}개")

# %%
# if __name__ == "__main__":
#     query = '("antibiotic overuse" OR "vitamin C" OR "mRNA vaccine" OR "inflammation" OR "immunotherapy" OR "low carb diet" OR "mental health stigma" OR "supplements" OR "herbal medicine") AND PUB_YEAR:2025'
#     process_all_pmc_articles(query)
