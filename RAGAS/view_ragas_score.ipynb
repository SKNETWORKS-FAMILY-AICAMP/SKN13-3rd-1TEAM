# %%
import pandas as pd

# CSV 파일 불러오기
df = pd.read_csv("ragas_score.csv")

# 데이터프레임 확인
df
# Out:
#                                            user_input  \
# 0   ICU 환자에게서 분리된 Acinetobacter baumannii에서 항생제 내성...
# 1   모바일 유전 요소(MGEs)의 수평 및 수직 전파 균형에 영향을 미치는 환경 변수는...
# 2                    AGXX®의 박멸 효과가 주로 어떤 메커니즘에 기반하는가?
# 3              항생제 내성(AMR)이 가축과 인간 건강에 미치는 영향은 무엇입니까?
# 4     E. fergusonii ACE12에서 확인된 4가지 항생제 내성 유전자는 무엇인가?
# 5       rs4588 SNP가 고관절 치환술에서 어떤 영향을 미칠 수 있다고 언급되었나요?
# 6           글루타치온이 스티븐스-존슨 증후군과 연관되어 있다고 보고된 사례가 있나요?
# 7      H. pylori가 위암을 유발하는 분자적 기전에는 어떤 변화가 포함되어 있습니까?
# 8   200 μg/L 농도의 납(Pb) 노출이 Bufo gargarizans 올챙이의 장...
# 9      Indoor TSP 시료에서 상대적으로 풍부하게 발견된 박테리아 종류는 무엇입니까?
# 10                                   이 연구의 목적은 무엇인가요?
# 11     이 연구에서 새롭게 도입한 두 개의 E. coli 대조주의 주요 특징은 무엇입니까?
# 12  Pseudomonas aeruginosa strain Ch39은 어떤 환경에서 분리...
# 13              정상 건강한 인구에서 25(OH)D의 정상 평균 수치는 얼마입니까?
# 14  Clostridium perfringens 감염이 유발할 수 있는 질병에는 무엇이 ...
# 15                                   이 연구의 목적은 무엇입니까?
# ...

# %%
import pandas as pd

# CSV 파일 불러오기
df2 = pd.read_csv("ragas_eval_result.csv")

# 데이터프레임 확인
df2
# Out:
#                                            user_input  \
# 0   ICU 환자에게서 분리된 Acinetobacter baumannii에서 항생제 내성...
# 1   모바일 유전 요소(MGEs)의 수평 및 수직 전파 균형에 영향을 미치는 환경 변수는...
# 2                    AGXX®의 박멸 효과가 주로 어떤 메커니즘에 기반하는가?
# 3              항생제 내성(AMR)이 가축과 인간 건강에 미치는 영향은 무엇입니까?
# 4     E. fergusonii ACE12에서 확인된 4가지 항생제 내성 유전자는 무엇인가?
# 5       rs4588 SNP가 고관절 치환술에서 어떤 영향을 미칠 수 있다고 언급되었나요?
# 6           글루타치온이 스티븐스-존슨 증후군과 연관되어 있다고 보고된 사례가 있나요?
# 7      H. pylori가 위암을 유발하는 분자적 기전에는 어떤 변화가 포함되어 있습니까?
# 8   200 μg/L 농도의 납(Pb) 노출이 Bufo gargarizans 올챙이의 장...
# 9      Indoor TSP 시료에서 상대적으로 풍부하게 발견된 박테리아 종류는 무엇입니까?
# 10                                   이 연구의 목적은 무엇인가요?
# 11     이 연구에서 새롭게 도입한 두 개의 E. coli 대조주의 주요 특징은 무엇입니까?
# 12  Pseudomonas aeruginosa strain Ch39은 어떤 환경에서 분리...
# 13              정상 건강한 인구에서 25(OH)D의 정상 평균 수치는 얼마입니까?
# 14  Clostridium perfringens 감염이 유발할 수 있는 질병에는 무엇이 ...
# 15                                   이 연구의 목적은 무엇입니까?
# ...
